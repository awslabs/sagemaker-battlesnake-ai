# %% [markdown]
# # Introduction
#
# This notebook outlines the steps involved in building and deploying a Battlesnake model using Ray RLlib and TensorFlow on Amazon SageMaker.
#
# Library versions currently in use:  TensorFlow 2.1, Ray RLlib 0.8.2
#
# The model is first trained using multi-agent PPO, and then deployed to a managed _TensorFlow Serving_ SageMaker endpoint that can be used for inference.
#
# <br/>
#
# **Note:** This is a work-in-progress...
#
# ### Comments and Known Issues
#
# * The CNN kernels in `cnn_tf.py` are currently fixed, which means they will likely require adjustment if you specify a map size other than 11x11
#   * it would be nice if this happened automagically
# * The current MultiAgentBattlesnake environment uses 2 frames for each observation. If you only want to use one frame, you'll need to adjust the observation code in `ma_battlesnake.py` accordingly
# * The original TF model export code in `ray_launcher.py` did not work for TF2.1.
#   * I switched over to RLlib's export_model() method, which seems to be working here
# * I have not yet tested RLlib's built-in `{'use_lstm': True}` model parameter, which wraps the CNN in an LSTM. This was working for local training/inference but has not been tested with the SageMaker inference endpoint, yet
# * Regardless of the number of snakes in the gym, or which policy is 'best', only policy_0 is currently exported as a TF model. Refer to `common/sagemaker_rl/tf_serving_utils.py` and see the comment in the inference section, below
# * The Ray dashboard fails to start (errors during training) but does not abort the training job
# * There are many warnings during training - most appear to be benign, but are annoying
# * Both local-mode and SageMaker-based training and inference have been tested, and appear to be working
#     * local-mode inference might generate some warnings, but seems to work regardless
# * GPU training/inference has not been tested
# * Single-instance training has been tested. Distributed multi-instance RLlib training has not yet been tested.
# * Although the hosted model is able to provide predictions, I haven't yet verified that the predictions are correct or useful.
# * The default hyperparameters are unlikely to generate an impressive model. Modify the hyperparameters and rewards if you are hoping to see something cool.

# %%
import sagemaker
from sagemaker.rl import RLEstimator, RLToolkit
import boto3

# %%
sm_session = sagemaker.session.Session()
s3_bucket = sm_session.default_bucket()

s3_output_path = 's3://{}/'.format(s3_bucket)
print("S3 bucket path: {}".format(s3_output_path))
# Out:
# S3 bucket path: s3://sagemaker-us-west-2-599069043765/

# %%
job_name_prefix = 'battlesnake-rllib-ppo'

role = sagemaker.get_execution_role()
print(role)
# Out:
# arn:aws:iam::599069043765:role/service-role/AmazonSageMaker-ExecutionRole-20191203T172993

# %%
# Change local_mode to True if you want to do local training within this Notebook instance
# Otherwise, we'll spin-up a SageMaker training instance to handle the training

local_mode = False

if local_mode:
    instance_type = 'local'
else:
    instance_type = "ml.m5.4xlarge"
    
# If training locally, do some Docker housekeeping..
if local_mode:
    # !/bin/bash ./common/setup.sh

# %%
# Specify the new TF v2.1 / Ray RLlib 0.8.2 container
#    Adjust 'cpu' or 'gpu' in the image name, as required
image_name = '462105765813.dkr.ecr.us-west-2.amazonaws.com/sagemaker-rl-ray-container:ray-0.8.2-tf-cpu-py36'

# %%
# %%time

# Define and execute our training job
# Adjust hyperparameters and train_instance_count accordingly

metric_definitions = RLEstimator.default_metric_definitions(RLToolkit.RAY)
    
estimator = RLEstimator(entry_point="train-mabs.py",
                        source_dir='src',
                        dependencies=["common/sagemaker_rl", "common/battlesnake_gym"],
                        image_name=image_name,
                        role=role,
                        train_instance_type=instance_type,
                        train_instance_count=1,
                        output_path=s3_output_path,
                        base_job_name=job_name_prefix,
                        metric_definitions=metric_definitions,
                        hyperparameters={
                            # See train-mabs.py to add additional hyperparameters
                            # Also see ray_launcher.py for the rl.training.* hyperparameters
                            #
                            # number of training iterations
                            "num_iters": 10,
                            # number of snakes in the gym
                            "num_agents": 5,
                            # dimension of the gym. changing this could require changes to CNN kernels
                            # in cnn_ft.py
                            "map_height": 11,
                        }
                    )

estimator.fit()

job_name = estimator.latest_training_job.job_name
print("Training job: %s" % job_name)
# Out:
# 2020-03-20 22:01:36 Starting - Starting the training job...
# 2020-03-20 22:01:39 Starting - Launching requested ML instances...
# 2020-03-20 22:02:36 Starting - Preparing the instances for training......
# 2020-03-20 22:03:29 Downloading - Downloading input data...
# 2020-03-20 22:03:38 Training - Downloading the training image.....bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2020-03-20 22:04:42,024 sagemaker-containers INFO     Imported framework sagemaker_tensorflow_container.training
# 2020-03-20 22:04:42,031 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-03-20 22:04:42,158 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-03-20 22:04:42,173 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-03-20 22:04:42,188 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-03-20 22:04:42,197 sagemaker-containers INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_estimator": "RLEstimator"
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "num_iters": 10,
#         "num_agents": 5,
#         "map_height": 11
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "battlesnake-rllib-ppo-2020-03-20-22-01-36-294",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-599069043765/battlesnake-rllib-ppo-2020-03-20-22-01-36-294/source/sourcedir.tar.gz",
#     "module_name": "train-mabs",
#     "network_interface_name": "eth0",
#     "num_cpus": 16,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train-mabs.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"map_height":11,"num_agents":5,"num_iters":10}
# SM_USER_ENTRY_POINT=train-mabs.py
# SM_FRAMEWORK_PARAMS={"sagemaker_estimator":"RLEstimator"}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train-mabs
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=16
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-599069043765/battlesnake-rllib-ppo-2020-03-20-22-01-36-294/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_estimator":"RLEstimator"},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"map_height":11,"num_agents":5,"num_iters":10},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"battlesnake-rllib-ppo-2020-03-20-22-01-36-294","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-599069043765/battlesnake-rllib-ppo-2020-03-20-22-01-36-294/source/sourcedir.tar.gz","module_name":"train-mabs","network_interface_name":"eth0","num_cpus":16,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train-mabs.py"}
# SM_USER_ARGS=["--map_height","11","--num_agents","5","--num_iters","10"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_NUM_ITERS=10
# SM_HP_NUM_AGENTS=5
# SM_HP_MAP_HEIGHT=11
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/lib/python36.zip:/usr/lib/python3.6:/usr/lib/python3.6/lib-dynload:/usr/local/lib/python3.6/dist-packages:/usr/lib/python3/dist-packages
#
# Invoking script with the following command:
#
# /usr/bin/python3 train-mabs.py --map_height 11 --num_agents 5 --num_iters 10
#
#
# 2020-03-20 22:04:45,302#011INFO resource_spec.py:212 -- Starting Ray with 33.59 GiB memory available for workers and up to 16.81 GiB for objects. You can adjust these settings with ray.init(memory=<bytes>, object_store_memory=<bytes>).
# 2020-03-20 22:04:45,713#011INFO services.py:1078 -- View the Ray dashboard at #033#033localhost:8265#033#033
# No checkpoint path specified. Training from scratch.
# Important! Ray with version <=7.2 may report "Did not find checkpoint file" even if the experiment is actually restored successfully. If restoration is expected, please check "training_iteration" in the experiment info to confirm.
# == Status ==
# Memory usage on this node: 2.8/61.5 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 16/16 CPUs, 0/0 GPUs, 0.0/33.59 GiB heap, 0.0/11.57 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+-------+
# | Trial name                            | status   | loc   |
# |---------------------------------------+----------+-------|
# | PPO_MultiAgentBattlesnake-v1_cf3b6376 | RUNNING  |       |
# +---------------------------------------+----------+-------+
#
#
# 2020-03-20 22:04:46,943#011WARNING worker.py:1058 -- The dashboard on node ip-10-0-207-160.us-west-2.compute.internal failed with the following error:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1062, in create_server
#     sock.bind(sa)
# OSError: [Errno 99] Cannot assign requested address
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/dashboard/dashboard.py", line 920, in <module>
#     dashboard.run()
#   File "/usr/local/lib/python3.6/dist-packages/ray/dashboard/dashboard.py", line 368, in run
#     aiohttp.web.run_app(self.app, host=self.host, port=self.port)
#   File "/usr/local/lib/python3.6/dist-packages/aiohttp/web.py", line 433, in run_app
#     reuse_port=reuse_port))
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 484, in run_until_complete
#     return future.result()
#   File "/usr/local/lib/python3.6/dist-packages/aiohttp/web.py", line 359, in _run_app
#     await site.start()
#   File "/usr/local/lib/python3.6/dist-packages/aiohttp/web_runner.py", line 104, in start
#     reuse_port=self._reuse_port)
#   File "/usr/lib/python3.6/asyncio/base_events.py", line 1066, in create_server
#     % (sa, err.strerror.lower()))
# OSError: [Errno 99] error while attempting to bind on address ('::1', 8265, 0, 0): cannot assign requested address
#
# #033#033(pid=145)#033 2020-03-20 22:04:48,626#011INFO trainer.py:420 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# #033#033(pid=145)#033 2020-03-20 22:04:48,640#011INFO trainer.py:580 -- Current log_level is ERROR. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# #033#033(pid=145)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=145)#033   obj = yaml.load(type_)
# #033#033(pid=145)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=145)#033   obj = yaml.load(type_)
# 2020-03-20 22:04:38 Training - Training image download completed. Training in progress.#033#033(pid=145)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=145)#033   obj = yaml.load(type_)
# #033#033(pid=145)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=145)#033   obj = yaml.load(type_)
# #033#033(pid=145)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=145)#033   obj = yaml.load(type_)
# #033#033(pid=142)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=142)#033   obj = yaml.load(type_)
# #033#033(pid=153)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=153)#033   obj = yaml.load(type_)
# #033#033(pid=144)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=144)#033   obj = yaml.load(type_)
# #033#033(pid=146)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=146)#033   obj = yaml.load(type_)
# #033#033(pid=150)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=150)#033   obj = yaml.load(type_)
# #033#033(pid=149)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=149)#033   obj = yaml.load(type_)
# #033#033(pid=151)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=151)#033   obj = yaml.load(type_)
# #033#033(pid=148)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=148)#033   obj = yaml.load(type_)
# #033#033(pid=138)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=138)#033   obj = yaml.load(type_)
# #033#033(pid=141)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=141)#033   obj = yaml.load(type_)
# #033#033(pid=143)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=143)#033   obj = yaml.load(type_)
# #033#033(pid=147)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=147)#033   obj = yaml.load(type_)
# #033#033(pid=140)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=140)#033   obj = yaml.load(type_)
# #033#033(pid=152)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=152)#033   obj = yaml.load(type_)
# #033#033(pid=139)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=139)#033   obj = yaml.load(type_)
# #033#033(pid=153)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=153)#033   obj = yaml.load(type_)
# #033#033(pid=149)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=149)#033   obj = yaml.load(type_)
# #033#033(pid=142)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=142)#033   obj = yaml.load(type_)
# #033#033(pid=144)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=144)#033   obj = yaml.load(type_)
# #033#033(pid=151)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=151)#033   obj = yaml.load(type_)
# #033#033(pid=150)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=150)#033   obj = yaml.load(type_)
# #033#033(pid=146)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=146)#033   obj = yaml.load(type_)
# #033#033(pid=148)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=148)#033   obj = yaml.load(type_)
# #033#033(pid=138)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=138)#033   obj = yaml.load(type_)
# #033#033(pid=141)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=141)#033   obj = yaml.load(type_)
# #033#033(pid=140)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=140)#033   obj = yaml.load(type_)
# #033#033(pid=143)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=143)#033   obj = yaml.load(type_)
# #033#033(pid=152)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=152)#033   obj = yaml.load(type_)
# #033#033(pid=147)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=147)#033   obj = yaml.load(type_)
# #033#033(pid=139)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=139)#033   obj = yaml.load(type_)
# #033#033(pid=153)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=153)#033   obj = yaml.load(type_)
# #033#033(pid=151)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=151)#033   obj = yaml.load(type_)
# #033#033(pid=144)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=144)#033   obj = yaml.load(type_)
# #033#033(pid=150)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=150)#033   obj = yaml.load(type_)
# #033#033(pid=149)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=149)#033   obj = yaml.load(type_)
# #033#033(pid=142)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=142)#033   obj = yaml.load(type_)
# #033#033(pid=146)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=146)#033   obj = yaml.load(type_)
# #033#033(pid=148)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=148)#033   obj = yaml.load(type_)
# #033#033(pid=141)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=141)#033   obj = yaml.load(type_)
# #033#033(pid=143)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=143)#033   obj = yaml.load(type_)
# #033#033(pid=152)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=152)#033   obj = yaml.load(type_)
# #033#033(pid=138)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=138)#033   obj = yaml.load(type_)
# #033#033(pid=140)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=140)#033   obj = yaml.load(type_)
# #033#033(pid=147)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=147)#033   obj = yaml.load(type_)
# #033#033(pid=139)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=139)#033   obj = yaml.load(type_)
# #033#033(pid=151)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=151)#033   obj = yaml.load(type_)
# #033#033(pid=150)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=150)#033   obj = yaml.load(type_)
# #033#033(pid=142)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=142)#033   obj = yaml.load(type_)
# #033#033(pid=146)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=146)#033   obj = yaml.load(type_)
# #033#033(pid=144)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=144)#033   obj = yaml.load(type_)
# #033#033(pid=149)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=149)#033   obj = yaml.load(type_)
# #033#033(pid=153)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=153)#033   obj = yaml.load(type_)
# #033#033(pid=148)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=148)#033   obj = yaml.load(type_)
# #033#033(pid=143)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=143)#033   obj = yaml.load(type_)
# #033#033(pid=152)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=152)#033   obj = yaml.load(type_)
# #033#033(pid=139)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=139)#033   obj = yaml.load(type_)
# #033#033(pid=140)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=140)#033   obj = yaml.load(type_)
# #033#033(pid=141)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=141)#033   obj = yaml.load(type_)
# #033#033(pid=138)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=138)#033   obj = yaml.load(type_)
# #033#033(pid=147)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=147)#033   obj = yaml.load(type_)
# #033#033(pid=151)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=151)#033   obj = yaml.load(type_)
# #033#033(pid=142)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=142)#033   obj = yaml.load(type_)
# #033#033(pid=146)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=146)#033   obj = yaml.load(type_)
# #033#033(pid=150)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=150)#033   obj = yaml.load(type_)
# #033#033(pid=152)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=152)#033   obj = yaml.load(type_)
# #033#033(pid=140)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=140)#033   obj = yaml.load(type_)
# #033#033(pid=149)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=149)#033   obj = yaml.load(type_)
# #033#033(pid=143)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=143)#033   obj = yaml.load(type_)
# #033#033(pid=148)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=148)#033   obj = yaml.load(type_)
# #033#033(pid=153)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=153)#033   obj = yaml.load(type_)
# #033#033(pid=144)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=144)#033   obj = yaml.load(type_)
# #033#033(pid=139)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=139)#033   obj = yaml.load(type_)
# #033#033(pid=141)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=141)#033   obj = yaml.load(type_)
# #033#033(pid=147)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=147)#033   obj = yaml.load(type_)
# #033#033(pid=138)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=138)#033   obj = yaml.load(type_)
# #033#033(pid=145)#033 2020-03-20 22:05:27,618#011INFO trainable.py:178 -- _setup took 38.992 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# Result for PPO_MultiAgentBattlesnake-v1_cf3b6376:
#   custom_metrics: {}
#   date: 2020-03-20_22-06-34
#   done: false
#   episode_len_mean: 4.412625096227868
#   episode_reward_max: 27.0
#   episode_reward_mean: -1.9214780600461894
#   episode_reward_min: -15.0
#   episodes_this_iter: 2598
#   episodes_total: 2598
#   experiment_id: 6b777adc731a4f3c8323165ca3c20cb9
#   experiment_tag: '0'
#   hostname: ip-10-0-207-160.us-west-2.compute.internal
#   info:
#     grad_time_ms: 23809.142
#     learner:
#       policy_0:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3616435527801514
#         entropy_coeff: 0.0
#         kl: 0.023356305435299873
#         policy_loss: -0.06204693019390106
#         total_loss: 2.0016069412231445
#         vf_explained_var: 0.277072936296463
#         vf_loss: 2.0589826107025146
#       policy_1:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.362338900566101
#         entropy_coeff: 0.0
#         kl: 0.023224402219057083
#         policy_loss: -0.06124798581004143
#         total_loss: 1.9936448335647583
#         vf_explained_var: 0.28902631998062134
#         vf_loss: 2.05024790763855
#       policy_2:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.363222599029541
#         entropy_coeff: 0.0
#         kl: 0.021892761811614037
#         policy_loss: -0.0565105639398098
#         total_loss: 1.9572906494140625
#         vf_explained_var: 0.29301175475120544
#         vf_loss: 2.009422540664673
#       policy_3:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3641875982284546
#         entropy_coeff: 0.0
#         kl: 0.021352188661694527
#         policy_loss: -0.05872636288404465
#         total_loss: 1.9562338590621948
#         vf_explained_var: 0.2923574447631836
#         vf_loss: 2.0106899738311768
#       policy_4:
#         cur_kl_coeff: 0.20000000298023224
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3618537187576294
#         entropy_coeff: 0.0
#         kl: 0.023020494729280472
#         policy_loss: -0.06199847161769867
#         total_loss: 1.8744279146194458
#         vf_explained_var: 0.29799574613571167
#         vf_loss: 1.9318221807479858
#     load_time_ms: 2344.814
#     num_steps_sampled: 11520
#     num_steps_trained: 11520
#     sample_time_ms: 12419.859
#     update_time_ms: 23857.425
#   iterations_since_restore: 1
#   node_ip: 10.0.207.160
#   num_healthy_workers: 15
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 20.42065217391304
#     ram_util_percent: 17.633695652173916
#   pid: 145
#   policy_reward_max:
#     policy_0: 17.0
#     policy_1: 16.0
#     policy_2: 17.0
#     policy_3: 14.0
#     policy_4: 14.0
#   policy_reward_mean:
#     policy_0: -0.38837567359507313
#     policy_1: -0.371824480369515
#     policy_2: -0.39376443418013857
#     policy_3: -0.35873749037721325
#     policy_4: -0.40877598152424943
#   policy_reward_min:
#     policy_0: -3.0
#     policy_1: -3.0
#     policy_2: -3.0
#     policy_3: -3.0
#     policy_4: -3.0
#   sampler_perf:
#     mean_env_wait_ms: 1.3767412771147536
#     mean_inference_ms: 23.84408334425596
#     mean_processing_ms: 2.929358348257391
#   time_since_restore: 63.967270851135254
#   time_this_iter_s: 63.967270851135254
#   time_total_s: 63.967270851135254
#   timestamp: 1584741994
#   timesteps_since_restore: 11520
#   timesteps_this_iter: 11520
#   timesteps_total: 11520
#   training_iteration: 1
#   trial_id: cf3b6376
#
# == Status ==
# Memory usage on this node: 11.6/61.5 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 16/16 CPUs, 0/0 GPUs, 0.0/33.59 GiB heap, 0.0/11.57 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+------------------+----------+------------------+-------+--------+
# | Trial name                            | status   | loc              |   reward |   total time (s) |    ts |   iter |
# |---------------------------------------+----------+------------------+----------+------------------+-------+--------|
# | PPO_MultiAgentBattlesnake-v1_cf3b6376 | RUNNING  | 10.0.207.160:145 | -1.92148 |          63.9673 | 11520 |      1 |
# +---------------------------------------+----------+------------------+----------+------------------+-------+--------+
#
#
# Result for PPO_MultiAgentBattlesnake-v1_cf3b6376:
#   custom_metrics: {}
#   date: 2020-03-20_22-07-00
#   done: false
#   episode_len_mean: 4.796419650291424
#   episode_reward_max: 27.0
#   episode_reward_mean: -0.828059950041632
#   episode_reward_min: -15.0
#   episodes_this_iter: 2402
#   episodes_total: 5000
#   experiment_id: 6b777adc731a4f3c8323165ca3c20cb9
#   experiment_tag: '0'
#   hostname: ip-10-0-207-160.us-west-2.compute.internal
#   info:
#     grad_time_ms: 19676.672
#     learner:
#       policy_0:
#         cur_kl_coeff: 0.30000001192092896
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3183457851409912
#         entropy_coeff: 0.0
#         kl: 0.027036942541599274
#         policy_loss: -0.09166321158409119
#         total_loss: 2.497037410736084
#         vf_explained_var: 0.30434393882751465
#         vf_loss: 2.580589532852173
#       policy_1:
#         cur_kl_coeff: 0.30000001192092896
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3193751573562622
#         entropy_coeff: 0.0
#         kl: 0.02972915954887867
#         policy_loss: -0.0973690003156662
#         total_loss: 2.4305644035339355
#         vf_explained_var: 0.3069911599159241
#         vf_loss: 2.519014596939087
#       policy_2:
#         cur_kl_coeff: 0.30000001192092896
#         cur_lr: 0.0005000000237487257
#         entropy: 1.322337031364441
#         entropy_coeff: 0.0
#         kl: 0.027177181094884872
#         policy_loss: -0.09325644373893738
#         total_loss: 2.4585673809051514
#         vf_explained_var: 0.29196327924728394
#         vf_loss: 2.543670654296875
#       policy_3:
#         cur_kl_coeff: 0.30000001192092896
#         cur_lr: 0.0005000000237487257
#         entropy: 1.3139898777008057
#         entropy_coeff: 0.0
#         kl: 0.030130548402667046
#         policy_loss: -0.09875782579183578
#         total_loss: 2.4217872619628906
#         vf_explained_var: 0.30909255146980286
#         vf_loss: 2.5115058422088623
#       policy_4:
#         cur_kl_coeff: 0.30000001192092896
#         cur_lr: 0.0005000000237487257
#         entropy: 1.307208776473999
#         entropy_coeff: 0.0
#         kl: 0.02949249930679798
#         policy_loss: -0.09604962915182114
#         total_loss: 2.6209919452667236
#         vf_explained_var: 0.30563393235206604
#         vf_loss: 2.7081940174102783
#     load_time_ms: 1366.166
#     num_steps_sampled: 23040
#     num_steps_trained: 23040
#     sample_time_ms: 11321.147
#     update_time_ms: 11938.548
#   iterations_since_restore: 2
#   node_ip: 10.0.207.160
#   num_healthy_workers: 15
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 26.488888888888887
#     ram_util_percent: 19.391666666666666
#   pid: 145
#   policy_reward_max:
#     policy_0: 17.0
#     policy_1: 16.0
#     policy_2: 15.0
#     policy_3: 15.0
#     policy_4: 16.0
#   policy_reward_mean:
#     policy_0: -0.3047460449625312
#     policy_1: -0.20233139050791007
#     policy_2: -0.24354704412989175
#     policy_3: -0.13821815154038303
#     policy_4: 0.06078268109908409
#   policy_reward_min:
#     policy_0: -3.0
#     policy_1: -3.0
#     policy_2: -3.0
#     policy_3: -3.0
#     policy_4: -3.0
#   sampler_perf:
#     mean_env_wait_ms: 1.370235672946481
#     mean_inference_ms: 22.57989813071005
#     mean_processing_ms: 2.8905587012140006
#   time_since_restore: 90.1824119091034
#   time_this_iter_s: 26.21514105796814
#   time_total_s: 90.1824119091034
#   timestamp: 1584742020
#   timesteps_since_restore: 23040
#   timesteps_this_iter: 11520
#   timesteps_total: 23040
#   training_iteration: 2
#   trial_id: cf3b6376
#
# == Status ==
# Memory usage on this node: 11.6/61.5 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 16/16 CPUs, 0/0 GPUs, 0.0/33.59 GiB heap, 0.0/11.57 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+------------------+----------+------------------+-------+--------+
# | Trial name                            | status   | loc              |   reward |   total time (s) |    ts |   iter |
# |---------------------------------------+----------+------------------+----------+------------------+-------+--------|
# | PPO_MultiAgentBattlesnake-v1_cf3b6376 | RUNNING  | 10.0.207.160:145 | -0.82806 |          90.1824 | 23040 |      2 |
# +---------------------------------------+----------+------------------+----------+------------------+-------+--------+
# Result for PPO_MultiAgentBattlesnake-v1_cf3b6376:
#   custom_metrics: {}
#   date: 2020-03-20_22-07-27
#   done: false
#   episode_len_mean: 5.8001009591115595
#   episode_reward_max: 43.0
#   episode_reward_mean: 2.2120141342756185
#   episode_reward_min: -15.0
#   episodes_this_iter: 1981
#   episodes_total: 6981
#   experiment_id: 6b777adc731a4f3c8323165ca3c20cb9
#   experiment_tag: '0'
#   hostname: ip-10-0-207-160.us-west-2.compute.internal
#   info:
#     grad_time_ms: 18322.211
#     learner:
#       policy_0:
#         cur_kl_coeff: 0.44999998807907104
#         cur_lr: 0.0005000000237487257
#         entropy: 1.2594250440597534
#         entropy_coeff: 0.0
#         kl: 0.029049284756183624
#         policy_loss: -0.10358740389347076
#         total_loss: 3.2191340923309326
#         vf_explained_var: 0.3344835937023163
#         vf_loss: 3.3096489906311035
#       policy_1:
#         cur_kl_coeff: 0.44999998807907104
#         cur_lr: 0.0005000000237487257
#         entropy: 1.2532711029052734
#         entropy_coeff: 0.0
#         kl: 0.030162878334522247
#         policy_loss: -0.10351565480232239
#         total_loss: 3.198272705078125
#         vf_explained_var: 0.35159775614738464
#         vf_loss: 3.288215160369873
#       policy_2:
#         cur_kl_coeff: 0.44999998807907104
#         cur_lr: 0.0005000000237487257
#         entropy: 1.2666797637939453
#         entropy_coeff: 0.0
#         kl: 0.028744056820869446
#         policy_loss: -0.10250089317560196
#         total_loss: 3.1550631523132324
#         vf_explained_var: 0.3413580060005188
#         vf_loss: 3.24462890625
#       policy_3:
#         cur_kl_coeff: 0.44999998807907104
#         cur_lr: 0.0005000000237487257
#         entropy: 1.2500115633010864
#         entropy_coeff: 0.0
#         kl: 0.029937908053398132
#         policy_loss: -0.10759366303682327
#         total_loss: 3.3682379722595215
#         vf_explained_var: 0.32792603969573975
#         vf_loss: 3.462359666824341
#       policy_4:
#         cur_kl_coeff: 0.44999998807907104
#         cur_lr: 0.0005000000237487257
#         entropy: 1.2367305755615234
#         entropy_coeff: 0.0
#         kl: 0.030027713626623154
#         policy_loss: -0.10884970426559448
#         total_loss: 3.4663383960723877
#         vf_explained_var: 0.31829530000686646
#         vf_loss: 3.5616753101348877
#     load_time_ms: 1032.725
#     num_steps_sampled: 34560
#     num_steps_trained: 34560
#     sample_time_ms: 10919.347
#     update_time_ms: 7966.613
#   iterations_since_restore: 3
#   node_ip: 10.0.207.160
#   num_healthy_workers: 15
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 26.022222222222222
#     ram_util_percent: 19.386111111111106
#   pid: 145
#   policy_reward_max:
#     policy_0: 17.0
#     policy_1: 21.0
#     policy_2: 17.0
#     policy_3: 21.0
#     policy_4: 18.0
#   policy_reward_mean:
#     policy_0: 0.2629984856133266
#     policy_1: 0.45835436648157496
#     policy_2: 0.2862190812720848
#     policy_3: 0.5189298334174659
#     policy_4: 0.6855123674911661
#   policy_reward_min:
#     policy_0: -3.0
#     policy_1: -3.0
#     policy_2: -3.0
#     policy_3: -3.0
#     policy_4: -3.0
#   sampler_perf:
#     mean_env_wait_ms: 1.3695778136296899
#     mean_inference_ms: 22.081135749333818
#     mean_processing_ms: 2.821621240692168
#   time_since_restore: 116.52996778488159
#   time_this_iter_s: 26.3475558757782
#   time_total_s: 116.52996778488159
#   timestamp: 1584742047
#   timesteps_since_restore: 34560
#   timesteps_this_iter: 11520
#   timesteps_total: 34560
#   training_iteration: 3
#   trial_id: cf3b6376
#
# == Status ==
# Memory usage on this node: 11.6/61.5 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 16/16 CPUs, 0/0 GPUs, 0.0/33.59 GiB heap, 0.0/11.57 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+------------------+----------+------------------+-------+--------+
# | Trial name                            | status   | loc              |   reward |   total time (s) |    ts |   iter |
# |---------------------------------------+----------+------------------+----------+------------------+-------+--------|
# | PPO_MultiAgentBattlesnake-v1_cf3b6376 | RUNNING  | 10.0.207.160:145 |  2.21201 |           116.53 | 34560 |      3 |
# +---------------------------------------+----------+------------------+----------+------------------+-------+--------+
#
#
# Result for PPO_MultiAgentBattlesnake-v1_cf3b6376:
#   custom_metrics: {}
#   date: 2020-03-20_22-07-53
#   done: false
#   episode_len_mean: 7.495424836601307
#   episode_reward_max: 51.0
#   episode_reward_mean: 7.112418300653594
#   episode_reward_min: -13.0
#   episodes_this_iter: 1530
#   episodes_total: 8511
#   experiment_id: 6b777adc731a4f3c8323165ca3c20cb9
#   experiment_tag: '0'
#   hostname: ip-10-0-207-160.us-west-2.compute.internal
#   info:
#     grad_time_ms: 17624.187
#     learner:
#       policy_0:
#         cur_kl_coeff: 0.675000011920929
#         cur_lr: 0.0005000000237487257
#         entropy: 1.2039095163345337
#         entropy_coeff: 0.0
#         kl: 0.02627539075911045
#         policy_loss: -0.10212624818086624
#         total_loss: 4.041992664337158
#         vf_explained_var: 0.3998175859451294
#         vf_loss: 4.126382827758789
#       policy_1:
#         cur_kl_coeff: 0.675000011920929
#         cur_lr: 0.0005000000237487257
#         entropy: 1.192737102508545
#         entropy_coeff: 0.0
#         kl: 0.02671005390584469
#         policy_loss: -0.09901788830757141
#         total_loss: 4.102423667907715
#         vf_explained_var: 0.4026757478713989
#         vf_loss: 4.183412075042725
#       policy_2:
#         cur_kl_coeff: 0.675000011920929
#         cur_lr: 0.0005000000237487257
#         entropy: 1.201869249343872
#         entropy_coeff: 0.0
#         kl: 0.02689012512564659
#         policy_loss: -0.10198289901018143
#         total_loss: 4.194685935974121
#         vf_explained_var: 0.39587825536727905
#         vf_loss: 4.278518199920654
#       policy_3:
#         cur_kl_coeff: 0.675000011920929
#         cur_lr: 0.0005000000237487257
#         entropy: 1.1923221349716187
#         entropy_coeff: 0.0
#         kl: 0.028031501919031143
#         policy_loss: -0.10106515139341354
#         total_loss: 4.494218826293945
#         vf_explained_var: 0.4043280780315399
#         vf_loss: 4.576362609863281
#       policy_4:
#         cur_kl_coeff: 0.675000011920929
#         cur_lr: 0.0005000000237487257
#         entropy: 1.1766971349716187
#         entropy_coeff: 0.0
#         kl: 0.027733834460377693
#         policy_loss: -0.1015937402844429
#         total_loss: 4.484866619110107
#         vf_explained_var: 0.3839932382106781
#         vf_loss: 4.567739963531494
#     load_time_ms: 874.324
#     num_steps_sampled: 46080
#     num_steps_trained: 46080
#     sample_time_ms: 10688.173
#     update_time_ms: 5979.065
#   iterations_since_restore: 4
#   node_ip: 10.0.207.160
#   num_healthy_workers: 15
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 25.67142857142857
#     ram_util_percent: 19.437142857142852
#   pid: 145
#   policy_reward_max:
#     policy_0: 23.0
#     policy_1: 24.0
#     policy_2: 26.0
#     policy_3: 26.0
#     policy_4: 24.0
#   policy_reward_mean:
#     policy_0: 1.0673202614379085
#     policy_1: 1.3450980392156864
#     policy_2: 1.219607843137255
#     policy_3: 1.6450980392156862
# ...
#         vf_loss: 12.632577896118164
#     load_time_ms: 624.731
#     num_steps_sampled: 92160
#     num_steps_trained: 92160
#     sample_time_ms: 10058.684
#     update_time_ms: 2998.349
#   iterations_since_restore: 8
#   node_ip: 10.0.207.160
#   num_healthy_workers: 15
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 25.252941176470593
#     ram_util_percent: 19.53529411764706
#   pid: 145
#   policy_reward_max:
#     policy_0: 55.0
#     policy_1: 63.0
#     policy_2: 59.0
#     policy_3: 62.0
#     policy_4: 70.0
#   policy_reward_mean:
#     policy_0: 6.6269349845201235
#     policy_1: 7.3993808049535605
#     policy_2: 6.9829721362229105
#     policy_3: 6.801857585139319
#     policy_4: 8.729102167182663
#   policy_reward_min:
#     policy_0: -3.0
#     policy_1: -3.0
#     policy_2: -3.0
#     policy_3: -3.0
#     policy_4: -3.0
#   sampler_perf:
#     mean_env_wait_ms: 1.3583103475029275
#     mean_inference_ms: 21.010176714027473
#     mean_processing_ms: 2.3516804538131066
#   time_since_restore: 241.43996143341064
#   time_this_iter_s: 24.940715074539185
#   time_total_s: 241.43996143341064
#   timestamp: 1584742172
#   timesteps_since_restore: 92160
#   timesteps_this_iter: 11520
#   timesteps_total: 92160
#   training_iteration: 8
#   trial_id: cf3b6376
#
# == Status ==
# Memory usage on this node: 11.7/61.5 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 16/16 CPUs, 0/0 GPUs, 0.0/33.59 GiB heap, 0.0/11.57 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+------------------+----------+------------------+-------+--------+
# | Trial name                            | status   | loc              |   reward |   total time (s) |    ts |   iter |
# |---------------------------------------+----------+------------------+----------+------------------+-------+--------|
# | PPO_MultiAgentBattlesnake-v1_cf3b6376 | RUNNING  | 10.0.207.160:145 |  36.5402 |           241.44 | 92160 |      8 |
# +---------------------------------------+----------+------------------+----------+------------------+-------+--------+
# Result for PPO_MultiAgentBattlesnake-v1_cf3b6376:
#   custom_metrics: {}
#   date: 2020-03-20_22-09-57
#   done: false
#   episode_len_mean: 21.741509433962264
#   episode_reward_max: 172.0
#   episode_reward_mean: 46.51320754716981
#   episode_reward_min: -5.0
#   episodes_this_iter: 530
#   episodes_total: 12567
#   experiment_id: 6b777adc731a4f3c8323165ca3c20cb9
#   experiment_tag: '0'
#   hostname: ip-10-0-207-160.us-west-2.compute.internal
#   info:
#     grad_time_ms: 16111.883
#     learner:
#       policy_0:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.0844929218292236
#         entropy_coeff: 0.0
#         kl: 0.014590064994990826
#         policy_loss: -0.07125009596347809
#         total_loss: 10.055526733398438
#         vf_explained_var: 0.6800039410591125
#         vf_loss: 10.104618072509766
#       policy_1:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.0302314758300781
#         entropy_coeff: 0.0
#         kl: 0.014665492810308933
#         policy_loss: -0.06796585768461227
#         total_loss: 13.088025093078613
#         vf_explained_var: 0.6922000646591187
#         vf_loss: 13.133718490600586
#       policy_2:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.0483323335647583
#         entropy_coeff: 0.0
#         kl: 0.014783859252929688
#         policy_loss: -0.070259690284729
#         total_loss: 13.0806884765625
#         vf_explained_var: 0.6691926717758179
#         vf_loss: 13.128496170043945
#       policy_3:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.0492485761642456
#         entropy_coeff: 0.0
#         kl: 0.015039663761854172
#         policy_loss: -0.06947604566812515
#         total_loss: 12.539408683776855
#         vf_explained_var: 0.6857417225837708
#         vf_loss: 12.586043357849121
#       policy_4:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.0437813997268677
#         entropy_coeff: 0.0
#         kl: 0.014490858651697636
#         policy_loss: -0.07337380200624466
#         total_loss: 14.11950969696045
#         vf_explained_var: 0.651792049407959
#         vf_loss: 14.170875549316406
#     load_time_ms: 595.804
#     num_steps_sampled: 103680
#     num_steps_trained: 103680
#     sample_time_ms: 9983.488
#     update_time_ms: 2667.229
#   iterations_since_restore: 9
#   node_ip: 10.0.207.160
#   num_healthy_workers: 15
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 25.124242424242425
#     ram_util_percent: 19.566666666666666
#   pid: 145
#   policy_reward_max:
#     policy_0: 61.0
#     policy_1: 83.0
#     policy_2: 59.0
#     policy_3: 77.0
#     policy_4: 63.0
#   policy_reward_mean:
#     policy_0: 7.3226415094339625
#     policy_1: 9.662264150943397
#     policy_2: 9.379245283018868
#     policy_3: 9.449056603773585
#     policy_4: 10.7
#   policy_reward_min:
#     policy_0: -3.0
#     policy_1: -3.0
#     policy_2: -3.0
#     policy_3: -3.0
#     policy_4: -3.0
#   sampler_perf:
#     mean_env_wait_ms: 1.3523639920240338
#     mean_inference_ms: 20.916528174276518
#     mean_processing_ms: 2.2916083980756032
#   time_since_restore: 266.2149748802185
#   time_this_iter_s: 24.77501344680786
#   time_total_s: 266.2149748802185
#   timestamp: 1584742197
#   timesteps_since_restore: 103680
#   timesteps_this_iter: 11520
#   timesteps_total: 103680
#   training_iteration: 9
#   trial_id: cf3b6376
#
# == Status ==
# Memory usage on this node: 11.7/61.5 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 16/16 CPUs, 0/0 GPUs, 0.0/33.59 GiB heap, 0.0/11.57 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+------------------+----------+------------------+--------+--------+
# | Trial name                            | status   | loc              |   reward |   total time (s) |     ts |   iter |
# |---------------------------------------+----------+------------------+----------+------------------+--------+--------|
# | PPO_MultiAgentBattlesnake-v1_cf3b6376 | RUNNING  | 10.0.207.160:145 |  46.5132 |          266.215 | 103680 |      9 |
# +---------------------------------------+----------+------------------+----------+------------------+--------+--------+
#
#
# Result for PPO_MultiAgentBattlesnake-v1_cf3b6376:
#   custom_metrics: {}
#   date: 2020-03-20_22-10-22
#   done: true
#   episode_len_mean: 24.445859872611464
#   episode_reward_max: 208.0
#   episode_reward_mean: 54.54564755838641
#   episode_reward_min: -4.0
#   episodes_this_iter: 471
#   episodes_total: 13038
#   experiment_id: 6b777adc731a4f3c8323165ca3c20cb9
#   experiment_tag: '0'
#   hostname: ip-10-0-207-160.us-west-2.compute.internal
#   info:
#     grad_time_ms: 16002.496
#     learner:
#       policy_0:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.039116382598877
#         entropy_coeff: 0.0
#         kl: 0.01481669582426548
#         policy_loss: -0.06851266324520111
#         total_loss: 13.141817092895508
#         vf_explained_var: 0.7094298601150513
#         vf_loss: 13.187827110290527
#       policy_1:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.017879605293274
#         entropy_coeff: 0.0
#         kl: 0.014181558042764664
#         policy_loss: -0.0663335993885994
#         total_loss: 15.484641075134277
#         vf_explained_var: 0.7156175971031189
#         vf_loss: 15.529438018798828
#       policy_2:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.033821940422058
#         entropy_coeff: 0.0
#         kl: 0.014698818325996399
#         policy_loss: -0.06590409576892853
#         total_loss: 14.778647422790527
#         vf_explained_var: 0.7136576175689697
#         vf_loss: 14.822227478027344
#       policy_3:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.0318442583084106
#         entropy_coeff: 0.0
#         kl: 0.014570437371730804
#         policy_loss: -0.06963817030191422
#         total_loss: 14.770218849182129
#         vf_explained_var: 0.7175381183624268
#         vf_loss: 14.817729949951172
#       policy_4:
#         cur_kl_coeff: 1.5187499523162842
#         cur_lr: 0.0005000000237487257
#         entropy: 1.026381254196167
#         entropy_coeff: 0.0
#         kl: 0.014211934059858322
#         policy_loss: -0.07041489332914352
#         total_loss: 15.076665878295898
#         vf_explained_var: 0.689313530921936
#         vf_loss: 15.125494956970215
#     load_time_ms: 571.576
#     num_steps_sampled: 115200
#     num_steps_trained: 115200
#     sample_time_ms: 9913.025
#     update_time_ms: 2402.249
#   iterations_since_restore: 10
#   node_ip: 10.0.207.160
#   num_healthy_workers: 15
#   off_policy_estimator: {}
#   perf:
#     cpu_util_percent: 24.78235294117647
#     ram_util_percent: 19.570588235294117
#   pid: 145
#   policy_reward_max:
#     policy_0: 68.0
#     policy_1: 70.0
#     policy_2: 92.0
#     policy_3: 86.0
#     policy_4: 84.0
#   policy_reward_mean:
#     policy_0: 9.774946921443737
#     policy_1: 10.590233545647559
#     policy_2: 10.418259023354565
#     policy_3: 11.023354564755838
#     policy_4: 12.738853503184714
#   policy_reward_min:
#     policy_0: -3.0
#     policy_1: -3.0
#     policy_2: -3.0
#     policy_3: -3.0
#     policy_4: -3.0
#   sampler_perf:
#     mean_env_wait_ms: 1.3492693220634204
#     mean_inference_ms: 20.792935915944124
#     mean_processing_ms: 2.235958999874811
#   time_since_restore: 290.90979838371277
#   time_this_iter_s: 24.694823503494263
#   time_total_s: 290.90979838371277
#   timestamp: 1584742222
#   timesteps_since_restore: 115200
#   timesteps_this_iter: 11520
#   timesteps_total: 115200
#   training_iteration: 10
#   trial_id: cf3b6376
#
# == Status ==
# Memory usage on this node: 11.7/61.5 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 16/16 CPUs, 0/0 GPUs, 0.0/33.59 GiB heap, 0.0/11.57 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 RUNNING)
# +---------------------------------------+----------+------------------+----------+------------------+--------+--------+
# | Trial name                            | status   | loc              |   reward |   total time (s) |     ts |   iter |
# |---------------------------------------+----------+------------------+----------+------------------+--------+--------|
# | PPO_MultiAgentBattlesnake-v1_cf3b6376 | RUNNING  | 10.0.207.160:145 |  54.5456 |           290.91 | 115200 |     10 |
# +---------------------------------------+----------+------------------+----------+------------------+--------+--------+
#
#
# == Status ==
# Memory usage on this node: 11.7/61.5 GiB
# Using FIFO scheduling algorithm.
# Resources requested: 0/16 CPUs, 0/0 GPUs, 0.0/33.59 GiB heap, 0.0/11.57 GiB objects
# Result logdir: /opt/ml/output/intermediate/training
# Number of trials: 1 (1 TERMINATED)
# +---------------------------------------+------------+-------+----------+------------------+--------+--------+
# | Trial name                            | status     | loc   |   reward |   total time (s) |     ts |   iter |
# |---------------------------------------+------------+-------+----------+------------------+--------+--------|
# | PPO_MultiAgentBattlesnake-v1_cf3b6376 | TERMINATED |       |  54.5456 |           290.91 | 115200 |     10 |
# +---------------------------------------+------------+-------+----------+------------------+--------+--------+
#
#
# Saved model configuration.
# Saved the checkpoint file /opt/ml/output/intermediate/training/PPO_MultiAgentBattlesnake-v1_cf3b6376_0_2020-03-20_22-04-45q_xnsn0n/checkpoint_10/checkpoint-10 as /opt/ml/model/checkpoint
# Saved the checkpoint file /opt/ml/output/intermediate/training/PPO_MultiAgentBattlesnake-v1_cf3b6376_0_2020-03-20_22-04-45q_xnsn0n/checkpoint_10/checkpoint-10.tune_metadata as /opt/ml/model/checkpoint.tune_metadata
# 2020-03-20 22:10:27,509#011INFO trainer.py:420 -- Tip: set 'eager': true or the --eager flag to enable TensorFlow eager execution
# 2020-03-20 22:10:27,514#011INFO trainer.py:580 -- Current log_level is ERROR. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   obj = yaml.load(type_)
# #033#033(pid=5403)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=5403)#033   obj = yaml.load(type_)
# #033#033(pid=5403)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=5403)#033   obj = yaml.load(type_)
# #033#033(pid=5403)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=5403)#033   obj = yaml.load(type_)
# #033#033(pid=5403)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=5403)#033   obj = yaml.load(type_)
# #033#033(pid=5403)#033 /usr/local/lib/python3.6/dist-packages/ray/rllib/utils/from_config.py:134: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
# #033#033(pid=5403)#033   obj = yaml.load(type_)
#
# 2020-03-20 22:11:05 Uploading - Uploading generated training model2020-03-20 22:10:55,934#011INFO trainable.py:178 -- _setup took 28.421 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# 2020-03-20 22:10:57,675#011WARNING trainable.py:210 -- Getting current IP.
# 2020-03-20 22:10:57,675#011INFO trainable.py:416 -- Restored on 10.0.207.160 from checkpoint: /opt/ml/model/checkpoint
# 2020-03-20 22:10:57,675#011INFO trainable.py:423 -- Current state after restoring: {'_iteration': 10, '_timesteps_total': 115200, '_time_total': 290.90979838371277, '_episodes_total': 13038}
# Saved TensorFlow serving model!
#
# 2020-03-20 22:11:02,477 sagemaker-containers INFO     Reporting training SUCCESS
#
# 2020-03-20 22:11:12 Completed - Training job completed
# Training seconds: 463
# Billable seconds: 463
# Training job: battlesnake-rllib-ppo-2020-03-20-22-01-36-294
# CPU times: user 1.39 s, sys: 74.6 ms, total: 1.46 s
# Wall time: 10min 16s

# %%
# Where is the model stored in S3?
estimator.model_data
# Out:
# 's3://sagemaker-us-west-2-599069043765/battlesnake-rllib-ppo-2020-03-20-22-01-36-294/output/model.tar.gz'

# %%
from sagemaker.tensorflow.serving import Model

model = Model(model_data=estimator.model_data,
              role=role,
              framework_version='2.1.0',
             )

if local_mode:
    inf_instance_type = 'local'
else:
    inf_instance_type = "ml.t2.medium"

# Deploy an inference endpoint
predictor = model.deploy(initial_instance_count=1, instance_type=inf_instance_type)
# Out:
# -----------!

# %%
# Spoof an observation from a Battlesnake environment, and get the predicted action from the model
#
# This example is using single observation for a 5-agent environment with an 11x11 map
# The last axis is 12 because the current MultiAgentEnv is concatenating 2 frames
#   5 agent maps + 1 food map = 6 maps total    6 maps * 2 frames = 12
#
# Note: this prediction is for the first policy in the environment "policy_0"
#   We need to fix this to export the 'best' policy, all policies, etc.
#   Also - the agent's policy # and position within the observation *does* currently matter.
#   For example, if we export policy_4 for inference, we need to ensure that the agent's current
#   snake representation (during inference) is located within index 4 of the observations (food is index 0)

import numpy as np
from time import time

fake_obs = np.zeros(shape=(1,11,11,12), dtype=np.float32).tolist()

test_data = {"inputs": { 'observations': fake_obs,
                        'prev_action': -1,
                        'is_training': False,
                        'prev_reward': -1,
                        'seq_lens': -1
                       } }
before = time()
result = predictor.predict(test_data)
elapsed = time() - before

print("Raw inference results:")
for key in sorted(result['outputs'].keys()):
    print("  ", key, ": ", result['outputs'][key])

print()
print("Our model predicts that the next action to take is: action", result['outputs']['actions'][0])
print()
print("Inference took %.2f ms" % (elapsed*1000))
# Out:
# Raw inference results:
#    action_logp :  [0.0]
#    action_prob :  [1.0]
#    actions :  [1]
#    behaviour_logits :  [[-0.0531836264, 0.0837905332, -0.113031864, 0.0553472936]]
#    vf_preds :  [-1.23689604]
#
# Our model predicts that the next action to take is: action 1
#
# Inference took 32.20 ms

# %%
# Uncomment and run to delete the endpoint
# predictor.delete_endpoint()
